# %%
import pandas as pd

# %%
df = pd.read_csv('features_ceo.csv.gz')

df.head()
# Out:
#    Unnamed: 0  year  casos_01  casos_1_3  casos_1_4  populacao_1  peak_week_1  \
# 0           0  2012  6.216606   6.822197   6.907755    14.774860    23.076748
# 1           1  2013  6.879356   6.519147   6.683361    14.789516    23.492432
# 2           2  2014  7.016610   8.057061   7.395722    14.841466    25.767739
# 3           3  2015  6.171701   7.419980   6.504288    14.863661    24.255435
# 4           4  2016  8.311890   6.839476   7.232010    14.885322    24.309548
#
#        R0_1  t_end_1  ep_dur_1  ...  temp_amp_1_current  temp_max_1_current  \
# 0  1.445276       42        41  ...            6.863607           24.980995
# 1  1.336368       47        46  ...            6.293606           25.424781
# 2  1.589026       41        38  ...            9.381624           27.743694
# 3  1.481125       40        39  ...           10.218541           29.311434
# 4  1.669811       38        33  ...            6.000116           25.523715
#
#    temp_min_1_current  precip_tot_1_current  rainy_day_1_current  \
# 0           18.117388             95.850180             3.433987
# 1           19.131175            135.339429             3.367296
# 2           18.362069             54.730601             3.295837
# 3           19.092893             21.829550             3.367296
# 4           19.523599            122.292329             3.433987
#
#    enso_1_current  latitude  longitude  peak_week  geocode
# 0           -1.08  -15.7795   -47.9297  23.492432  5300108
# 1           -0.05  -15.7795   -47.9297  25.767739  5300108
# 2           -0.51  -15.7795   -47.9297  24.255435  5300108
# 3            0.23  -15.7795   -47.9297  24.309548  5300108
# 4            1.95  -15.7795   -47.9297  17.717438  5300108
#
# [5 rows x 35 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'year', 'casos_01', 'casos_1_3', 'casos_1_4',
#        'populacao_1', 'peak_week_1', 'R0_1', 't_end_1', 'ep_dur_1', 'dummy_ep',
#        'temp_med_4', 'temp_amp_4', 'temp_max_4', 'temp_min_4', 'umid_min_4',
#        'umid_max_4', 'umid_amp_4', 'enso_4', 'precip_tot_4', 'rainy_day_4',
#        'thr_temp_min_4', 'thr_temp_amp_4', 'thr_umid_med_4',
#        'temp_med_1_current', 'temp_amp_1_current', 'temp_max_1_current',
#        'temp_min_1_current', 'precip_tot_1_current', 'rainy_day_1_current',
#        'enso_1_current', 'latitude', 'longitude', 'peak_week', 'geocode'],
#       dtype='object')

# %%
predictors = [
'year',
    'geocode', 
'casos_01',
#'casos_1', 
'casos_1_3',
'casos_1_4',
'populacao_1',
'peak_week_1',
#'ep_pw_1', 
'R0_1',
#'ep_ini_1',
#'ep_end_1',
't_end_1', 
'ep_dur_1',
#'R0_est',
#peak_week
'dummy_ep',      
'temp_med_4',
'temp_amp_4',
'temp_max_4',
'temp_min_4', 
'umid_min_4',
'umid_max_4', 'umid_amp_4', 'enso_4',
'precip_tot_4', 'rainy_day_4', 'thr_temp_min_4', 'thr_temp_amp_4', 'thr_umid_med_4',      
'temp_med_1_current',
'temp_amp_1_current',
'temp_max_1_current',
'temp_min_1_current',
'precip_tot_1_current',
'rainy_day_1_current',
'enso_1_current', 
'latitude', 'longitude']

# %%
len(predictors)
# Out:
# 32

# %%
df = pd.read_csv('features_AC_nov.csv.gz')

df.head()
# Out:
#    geocode  year  casos  casos_1  casos_1_1  casos_1_2  casos_1_3  casos_1_4  \
# 0  1200013  2011    199      643      370.0       13.0        7.0      253.0
# 1  1200013  2012     74      199      183.0        4.0        2.0       10.0
# 2  1200013  2013    579       74       48.0        7.0        1.0       18.0
# 3  1200013  2014     16      579      455.0      112.0        2.0       10.0
# 4  1200013  2015      9       16       16.0        0.0        0.0        0.0
#
#    populacao  populacao_1  ...  enso_9_last  enso_9_current  enso_10_last  \
# 0    12778.0      12538.0  ...        -2.28           -1.16         -2.18
# 1    13011.0      12778.0  ...        -1.16           -0.32         -1.37
# 2    13353.0      13011.0  ...        -0.32           -0.38         -0.22
# 3    13613.0      13353.0  ...        -0.38           -0.15         -0.16
# 4    13869.0      13613.0  ...        -0.15            2.21          0.06
#
#    enso_10_current  enso_11_last  enso_11_current  enso_12_last  \
# 0            -1.37         -2.03            -1.21         -1.91
# 1            -0.22         -1.21            -0.07         -1.24
# 2            -0.16         -0.07            -0.17         -0.06
# 3             0.06         -0.17             0.34         -0.35
# 4             2.11          0.34             1.88          0.34
#
#    enso_12_current  latitude  longitude
# 0            -1.24  -9.82581   -66.8972
# 1            -0.06  -9.82581   -66.8972
# 2            -0.35  -9.82581   -66.8972
# 3             0.34  -9.82581   -66.8972
# 4             1.90  -9.82581   -66.8972
#
# [5 rows x 345 columns]

# %%
df[predictors]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df[predictors]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/train_lstm/lib/python3.12/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/train_lstm/lib/python3.12/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/train_lstm/lib/python3.12/site-packages/pandas/core/indexes/base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['casos_01', 'temp_med_4', 'temp_amp_4', 'temp_max_4', 'temp_min_4', 'umid_min_4', 'umid_max_4', 'umid_amp_4', 'enso_4', 'precip_tot_4', 'rainy_day_4', 'thr_temp_min_4', 'thr_temp_amp_4', 'thr_umid_med_4'] not in index"

# %%
for col in df.columns:

    print(col)
# Out:
# geocode
# year
# casos
# casos_1
# casos_1_1
# casos_1_2
# casos_1_3
# casos_1_4
# populacao
# populacao_1
# peak_week_1
# R0_1
# t_ini_1
# t_end_1
# ep_ini_1
# ep_end_1
# ep_dur_1
# ep_pw_1
# total_cases_1
# R0
# peak_week
# total_cases
# ep_pw
# sum_res
# dummy_ep
# inc
# inc_1
# inc_1_1
# inc_1_2
# inc_1_3
# inc_1_4
# temp_med_1_last
# temp_amp_1_last
# temp_max_1_last
# temp_min_1_last
# umid_min_1_last
# umid_max_1_last
# umid_amp_1_last
# temp_med_1_current
# temp_amp_1_current
# temp_max_1_current
# temp_min_1_current
# umid_min_1_current
# umid_max_1_current
# umid_amp_1_current
# temp_med_2_last
# temp_amp_2_last
# temp_max_2_last
# temp_min_2_last
# umid_min_2_last
# umid_max_2_last
# umid_amp_2_last
# temp_med_2_current
# temp_amp_2_current
# temp_max_2_current
# temp_min_2_current
# umid_min_2_current
# umid_max_2_current
# umid_amp_2_current
# temp_med_3_last
# temp_amp_3_last
# temp_max_3_last
# temp_min_3_last
# umid_min_3_last
# umid_max_3_last
# umid_amp_3_last
# temp_med_3_current
# temp_amp_3_current
# temp_max_3_current
# temp_min_3_current
# umid_min_3_current
# umid_max_3_current
# umid_amp_3_current
# temp_med_4_last
# temp_amp_4_last
# temp_max_4_last
# temp_min_4_last
# umid_min_4_last
# umid_max_4_last
# umid_amp_4_last
# temp_med_4_current
# temp_amp_4_current
# temp_max_4_current
# temp_min_4_current
# umid_min_4_current
# umid_max_4_current
# umid_amp_4_current
# temp_med_5_last
# temp_amp_5_last
# temp_max_5_last
# temp_min_5_last
# umid_min_5_last
# umid_max_5_last
# umid_amp_5_last
# temp_med_5_current
# temp_amp_5_current
# temp_max_5_current
# temp_min_5_current
# umid_min_5_current
# umid_max_5_current
# umid_amp_5_current
# temp_med_6_last
# temp_amp_6_last
# temp_max_6_last
# temp_min_6_last
# umid_min_6_last
# umid_max_6_last
# umid_amp_6_last
# temp_med_6_current
# temp_amp_6_current
# temp_max_6_current
# temp_min_6_current
# umid_min_6_current
# umid_max_6_current
# umid_amp_6_current
# temp_med_7_last
# temp_amp_7_last
# temp_max_7_last
# temp_min_7_last
# umid_min_7_last
# umid_max_7_last
# umid_amp_7_last
# temp_med_7_current
# temp_amp_7_current
# temp_max_7_current
# temp_min_7_current
# umid_min_7_current
# umid_max_7_current
# umid_amp_7_current
# temp_med_8_last
# temp_amp_8_last
# temp_max_8_last
# temp_min_8_last
# umid_min_8_last
# umid_max_8_last
# umid_amp_8_last
# temp_med_8_current
# temp_amp_8_current
# temp_max_8_current
# temp_min_8_current
# umid_min_8_current
# umid_max_8_current
# umid_amp_8_current
# temp_med_9_last
# temp_amp_9_last
# temp_max_9_last
# temp_min_9_last
# umid_min_9_last
# umid_max_9_last
# umid_amp_9_last
# temp_med_9_current
# temp_amp_9_current
# temp_max_9_current
# temp_min_9_current
# umid_min_9_current
# umid_max_9_current
# umid_amp_9_current
# temp_med_10_last
# temp_amp_10_last
# temp_max_10_last
# temp_min_10_last
# umid_min_10_last
# umid_max_10_last
# umid_amp_10_last
# temp_med_10_current
# temp_amp_10_current
# temp_max_10_current
# temp_min_10_current
# umid_min_10_current
# umid_max_10_current
# umid_amp_10_current
# temp_med_11_last
# temp_amp_11_last
# temp_max_11_last
# temp_min_11_last
# umid_min_11_last
# umid_max_11_last
# umid_amp_11_last
# temp_med_11_current
# temp_amp_11_current
# temp_max_11_current
# temp_min_11_current
# umid_min_11_current
# umid_max_11_current
# umid_amp_11_current
# temp_med_12_last
# temp_amp_12_last
# temp_max_12_last
# temp_min_12_last
# umid_min_12_last
# umid_max_12_last
# umid_amp_12_last
# temp_med_12_current
# temp_amp_12_current
# temp_max_12_current
# temp_min_12_current
# umid_min_12_current
# umid_max_12_current
# umid_amp_12_current
# precip_tot_1_last
# rainy_day_1_last
# thr_temp_min_1_last
# thr_temp_amp_1_last
# thr_umid_med_1_last
# precip_tot_1_current
# rainy_day_1_current
# thr_temp_min_1_current
# thr_temp_amp_1_current
# thr_umid_med_1_current
# precip_tot_2_last
# rainy_day_2_last
# thr_temp_min_2_last
# thr_temp_amp_2_last
# thr_umid_med_2_last
# precip_tot_2_current
# rainy_day_2_current
# thr_temp_min_2_current
# thr_temp_amp_2_current
# thr_umid_med_2_current
# precip_tot_3_last
# rainy_day_3_last
# thr_temp_min_3_last
# thr_temp_amp_3_last
# thr_umid_med_3_last
# precip_tot_3_current
# rainy_day_3_current
# thr_temp_min_3_current
# thr_temp_amp_3_current
# thr_umid_med_3_current
# precip_tot_4_last
# rainy_day_4_last
# thr_temp_min_4_last
# thr_temp_amp_4_last
# thr_umid_med_4_last
# precip_tot_4_current
# rainy_day_4_current
# thr_temp_min_4_current
# thr_temp_amp_4_current
# thr_umid_med_4_current
# precip_tot_5_last
# rainy_day_5_last
# thr_temp_min_5_last
# thr_temp_amp_5_last
# thr_umid_med_5_last
# precip_tot_5_current
# rainy_day_5_current
# thr_temp_min_5_current
# thr_temp_amp_5_current
# thr_umid_med_5_current
# precip_tot_6_last
# rainy_day_6_last
# thr_temp_min_6_last
# thr_temp_amp_6_last
# thr_umid_med_6_last
# precip_tot_6_current
# rainy_day_6_current
# thr_temp_min_6_current
# thr_temp_amp_6_current
# thr_umid_med_6_current
# precip_tot_7_last
# rainy_day_7_last
# thr_temp_min_7_last
# thr_temp_amp_7_last
# thr_umid_med_7_last
# precip_tot_7_current
# rainy_day_7_current
# thr_temp_min_7_current
# thr_temp_amp_7_current
# thr_umid_med_7_current
# precip_tot_8_last
# rainy_day_8_last
# thr_temp_min_8_last
# thr_temp_amp_8_last
# thr_umid_med_8_last
# precip_tot_8_current
# rainy_day_8_current
# thr_temp_min_8_current
# thr_temp_amp_8_current
# thr_umid_med_8_current
# precip_tot_9_last
# rainy_day_9_last
# thr_temp_min_9_last
# thr_temp_amp_9_last
# thr_umid_med_9_last
# precip_tot_9_current
# rainy_day_9_current
# thr_temp_min_9_current
# thr_temp_amp_9_current
# thr_umid_med_9_current
# precip_tot_10_last
# rainy_day_10_last
# thr_temp_min_10_last
# thr_temp_amp_10_last
# thr_umid_med_10_last
# precip_tot_10_current
# rainy_day_10_current
# thr_temp_min_10_current
# thr_temp_amp_10_current
# thr_umid_med_10_current
# precip_tot_11_last
# rainy_day_11_last
# thr_temp_min_11_last
# thr_temp_amp_11_last
# thr_umid_med_11_last
# precip_tot_11_current
# rainy_day_11_current
# thr_temp_min_11_current
# thr_temp_amp_11_current
# thr_umid_med_11_current
# precip_tot_12_last
# rainy_day_12_last
# thr_temp_min_12_last
# thr_temp_amp_12_last
# thr_umid_med_12_last
# precip_tot_12_current
# rainy_day_12_current
# thr_temp_min_12_current
# thr_temp_amp_12_current
# thr_umid_med_12_current
# enso_1_last
# enso_1_current
# enso_2_last
# enso_2_current
# enso_3_last
# enso_3_current
# enso_4_last
# enso_4_current
# enso_5_last
# enso_5_current
# enso_6_last
# enso_6_current
# enso_7_last
# enso_7_current
# enso_8_last
# enso_8_current
# enso_9_last
# enso_9_current
# enso_10_last
# enso_10_current
# enso_11_last
# enso_11_current
# enso_12_last
# enso_12_current
# latitude
# longitude
